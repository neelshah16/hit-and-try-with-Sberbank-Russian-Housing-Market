# %%
import pandas as pd
import seaborn as sns
import numpy as np
import matplotlib.pyplot as plt
# %matplotlib inline
plt.style.use('ggplot')

from sklearn import model_selection, preprocessing

df_train = pd.read_csv('train.csv')
df_test = pd.read_csv('test.csv')
df_extra = pd.read_csv('macro.csv')

print(np.size(df_train, 0))
print(np.size(df_test, 0))

df_test['price_doc'] = df_train['price_doc'].mean()

df = pd.concat([df_train, df_test])
print(np.size(df,0))
# Out:
# 30471
# 7662
# 38133

# %%
corr = df.corr()
sns.heatmap(corr)

# %%
corr
# Out:
#                           church_synagogue_km  oil_chemistry_km  \
# church_synagogue_km                  1.000000          0.375747
# oil_chemistry_km                     0.375747          1.000000
# railroad_station_avto_km            -0.019510          0.337798
# mosque_km                            0.352877          0.604519
# market_shop_km                       0.444147          0.544809
# metro_min_walk                       0.524521          0.710908
# metro_min_avto                       0.406803          0.704945
# radiation_km                         0.490285          0.825608
# big_church_km                        0.498004          0.575896
# workplaces_km                        0.491857          0.660830
# office_km                            0.419331          0.441961
# zd_vokzaly_avto_km                   0.442446          0.751050
# build_year                          -0.002849         -0.001666
# full_all                            -0.006376         -0.204466
# material                            -0.010923         -0.016501
# cafe_count_1000                     -0.209946         -0.200031
# floor                               -0.072121          0.039857
# cafe_count_500                      -0.208903         -0.201127
# cafe_count_2000                     -0.219401         -0.215262
# state                               -0.111106         -0.250396
# 0_13_all                            -0.056009         -0.325799
# work_all                            -0.084552         -0.393560
# cafe_count_3000                     -0.234331         -0.237411
# university_top_20_raion             -0.215939         -0.204931
# mosque_count_5000                   -0.262826         -0.175480
# full_sq                             -0.011900          0.054125
# num_room                            -0.040384         -0.031252
#
#                           railroad_station_avto_km  mosque_km  market_shop_km  \
# church_synagogue_km                      -0.019510   0.352877        0.444147
# oil_chemistry_km                          0.337798   0.604519        0.544809
# railroad_station_avto_km                  1.000000   0.071008        0.382697
# mosque_km                                 0.071008   1.000000        0.338457
# market_shop_km                            0.382697   0.338457        1.000000
# metro_min_walk                            0.337321   0.707840        0.589881
# metro_min_avto                            0.407811   0.694619        0.534934
# radiation_km                              0.292751   0.790476        0.600721
# big_church_km                             0.520415   0.503515        0.676933
# workplaces_km                             0.432397   0.462988        0.749417
# office_km                                 0.480485   0.355570        0.605919
# zd_vokzaly_avto_km                        0.434040   0.692427        0.654023
# build_year                                0.002819  -0.006136       -0.002197
# full_all                                 -0.147224   0.005030       -0.093655
# material                                  0.027082  -0.045411        0.010800
# cafe_count_1000                          -0.084897  -0.238406       -0.199326
# floor                                     0.014626   0.011965       -0.003653
# cafe_count_500                           -0.091348  -0.236498       -0.203870
# cafe_count_2000                          -0.096248  -0.255036       -0.205261
# state                                    -0.216555  -0.165886       -0.305063
# 0_13_all                                 -0.315710  -0.160341       -0.430764
# work_all                                 -0.340946  -0.182544       -0.480692
# cafe_count_3000                          -0.119872  -0.282973       -0.221557
# university_top_20_raion                  -0.074759  -0.275572       -0.177462
# mosque_count_5000                        -0.040635  -0.591741       -0.169314
# full_sq                                   0.034896   0.019045        0.026969
# num_room                                 -0.047315  -0.032925       -0.055780
#
#                           metro_min_walk  metro_min_avto  radiation_km  \
# church_synagogue_km             0.524521        0.406803      0.490285
# oil_chemistry_km                0.710908        0.704945      0.825608
# railroad_station_avto_km        0.337321        0.407811      0.292751
# mosque_km                       0.707840        0.694619      0.790476
# market_shop_km                  0.589881        0.534934      0.600721
# metro_min_walk                  1.000000        0.937427      0.911000
# metro_min_avto                  0.937427        1.000000      0.867878
# radiation_km                    0.911000        0.867878      1.000000
# big_church_km                   0.823206        0.764226      0.773403
# workplaces_km                   0.720896        0.639611      0.796999
# office_km                       0.577606        0.498762      0.626164
# zd_vokzaly_avto_km              0.756250        0.750421      0.850947
# build_year                     -0.003383       -0.002058     -0.004096
# full_all                       -0.072979       -0.075537     -0.139198
# material                        0.012187        0.018027     -0.021922
# cafe_count_1000                -0.130236       -0.152238     -0.166701
# floor                          -0.080413       -0.072240     -0.022316
# cafe_count_500                 -0.138053       -0.160597     -0.168601
# cafe_count_2000                -0.136114       -0.158343     -0.177373
# state                          -0.184665       -0.173894     -0.251271
# 0_13_all                       -0.315728       -0.325683     -0.373682
# work_all                       -0.347497       -0.358451     -0.415963
# cafe_count_3000                -0.152966       -0.176598     -0.197963
# university_top_20_raion        -0.124102       -0.139971     -0.178499
# mosque_count_5000              -0.210507       -0.221972     -0.285316
# full_sq                         0.028248        0.025381      0.033010
# num_room                       -0.040276       -0.046615     -0.047726
#
#                           big_church_km  workplaces_km    ...     \
# church_synagogue_km            0.498004       0.491857    ...
# oil_chemistry_km               0.575896       0.660830    ...
# railroad_station_avto_km       0.520415       0.432397    ...
# mosque_km                      0.503515       0.462988    ...
# market_shop_km                 0.676933       0.749417    ...
# metro_min_walk                 0.823206       0.720896    ...
# metro_min_avto                 0.764226       0.639611    ...
# radiation_km                   0.773403       0.796999    ...
# big_church_km                  1.000000       0.860417    ...
# workplaces_km                  0.860417       1.000000    ...
# office_km                      0.740504       0.819834    ...
# zd_vokzaly_avto_km             0.740738       0.805249    ...
# build_year                    -0.001565      -0.003481    ...
# full_all                      -0.103038      -0.164402    ...
# material                       0.011843      -0.027215    ...
# cafe_count_1000               -0.179013      -0.168169    ...
# floor                         -0.054221      -0.013195    ...
# cafe_count_500                -0.184229      -0.173657    ...
# cafe_count_2000               -0.188637      -0.178754    ...
# state                         -0.252795      -0.332179    ...
# 0_13_all                      -0.357067      -0.457887    ...
# work_all                      -0.386042      -0.500060    ...
# cafe_count_3000               -0.207309      -0.200723    ...
# university_top_20_raion       -0.165654      -0.142864    ...
# mosque_count_5000             -0.221879      -0.202537    ...
# full_sq                        0.037649       0.041267    ...
# num_room                      -0.054478      -0.075913    ...
#
#                           cafe_count_500  cafe_count_2000     state  0_13_all  \
# church_synagogue_km            -0.208903        -0.219401 -0.111106 -0.056009
# oil_chemistry_km               -0.201127        -0.215262 -0.250396 -0.325799
# railroad_station_avto_km       -0.091348        -0.096248 -0.216555 -0.315710
# mosque_km                      -0.236498        -0.255036 -0.165886 -0.160341
# market_shop_km                 -0.203870        -0.205261 -0.305063 -0.430764
# metro_min_walk                 -0.138053        -0.136114 -0.184665 -0.315728
# metro_min_avto                 -0.160597        -0.158343 -0.173894 -0.325683
# radiation_km                   -0.168601        -0.177373 -0.251271 -0.373682
# big_church_km                  -0.184229        -0.188637 -0.252795 -0.357067
# workplaces_km                  -0.173657        -0.178754 -0.332179 -0.457887
# office_km                      -0.216305        -0.224376 -0.292893 -0.402643
# zd_vokzaly_avto_km             -0.333985        -0.353797 -0.277247 -0.358864
# build_year                      0.002244         0.001547  0.251664  0.000546
# full_all                       -0.005747        -0.011719  0.110158  0.166072
# material                       -0.012718        -0.009368 -0.053151 -0.058703
# cafe_count_1000                 0.970419         0.989144 -0.068077  0.036242
# floor                          -0.000333        -0.006543 -0.107982 -0.004653
# cafe_count_500                  1.000000         0.959477 -0.053517  0.042328
# cafe_count_2000                 0.959477         1.000000 -0.061409  0.027227
# state                          -0.053517        -0.061409  1.000000  0.323990
# 0_13_all                        0.042328         0.027227  0.323990  1.000000
# work_all                        0.011647        -0.000613  0.367453  0.956119
# cafe_count_3000                 0.943898         0.989117 -0.043987  0.021629
# university_top_20_raion         0.683911         0.717752 -0.013106  0.017197
# mosque_count_5000               0.473407         0.502868  0.098401 -0.004228
# full_sq                         0.041847         0.038189 -0.077838 -0.018710
# num_room                        0.049676         0.044837  0.093931  0.074074
#
#                           work_all  cafe_count_3000  university_top_20_raion  \
# church_synagogue_km      -0.084552        -0.234331                -0.215939
# oil_chemistry_km         -0.393560        -0.237411                -0.204931
# railroad_station_avto_km -0.340946        -0.119872                -0.074759
# mosque_km                -0.182544        -0.282973                -0.275572
# market_shop_km           -0.480692        -0.221557                -0.177462
# metro_min_walk           -0.347497        -0.152966                -0.124102
# metro_min_avto           -0.358451        -0.176598                -0.139971
# radiation_km             -0.415963        -0.197963                -0.178499
# big_church_km            -0.386042        -0.207309                -0.165654
# workplaces_km            -0.500060        -0.200723                -0.142864
# office_km                -0.446339        -0.249826                -0.211444
# zd_vokzaly_avto_km       -0.409886        -0.399123                -0.330210
# build_year                0.001631         0.001351                -0.002272
# full_all                  0.195674        -0.010903                -0.020842
# material                 -0.056104         0.003127                 0.038603
# cafe_count_1000           0.005279         0.969124                 0.702269
# floor                    -0.027961        -0.016719                -0.006267
# cafe_count_500            0.011647         0.943898                 0.683911
# cafe_count_2000          -0.000613         0.989117                 0.717752
# state                     0.367453        -0.043987                -0.013106
# 0_13_all                  0.956119         0.021629                 0.017197
# work_all                  1.000000        -0.002637                 0.010152
# cafe_count_3000          -0.002637         1.000000                 0.730665
# university_top_20_raion   0.010152         0.730665                 1.000000
# mosque_count_5000         0.004347         0.528032                 0.510132
# full_sq                  -0.032459         0.039826                 0.047253
# num_room                  0.079978         0.051589                 0.048362
#
#                           mosque_count_5000   full_sq  num_room
# church_synagogue_km               -0.262826 -0.011900 -0.040384
# oil_chemistry_km                  -0.175480  0.054125 -0.031252
# railroad_station_avto_km          -0.040635  0.034896 -0.047315
# mosque_km                         -0.591741  0.019045 -0.032925
# market_shop_km                    -0.169314  0.026969 -0.055780
# metro_min_walk                    -0.210507  0.028248 -0.040276
# metro_min_avto                    -0.221972  0.025381 -0.046615
# radiation_km                      -0.285316  0.033010 -0.047726
# big_church_km                     -0.221879  0.037649 -0.054478
# workplaces_km                     -0.202537  0.041267 -0.075913
# office_km                         -0.220527  0.027733 -0.080896
# zd_vokzaly_avto_km                -0.392499  0.031414 -0.081962
# build_year                         0.016676 -0.005233 -0.006901
# full_all                          -0.075693  0.013148  0.016783
# material                           0.041210  0.039400 -0.022858
# cafe_count_1000                    0.481739  0.037232  0.043028
# floor                             -0.013360  0.091234 -0.008977
# cafe_count_500                     0.473407  0.041847  0.049676
# cafe_count_2000                    0.502868  0.038189  0.044837
# state                              0.098401 -0.077838  0.093931
# 0_13_all                          -0.004228 -0.018710  0.074074
# work_all                           0.004347 -0.032459  0.079978
# cafe_count_3000                    0.528032  0.039826  0.051589
# university_top_20_raion            0.510132  0.047253  0.048362
# mosque_count_5000                  1.000000  0.024393  0.066531
# full_sq                            0.024393  1.000000  0.702255
# num_room                           0.066531  0.702255  1.000000
#
# [27 rows x 27 columns]

# %%
x = np.arange(0,10)

# %%
y = x**2

# %%
df_1 = pd.DataFrame([x, x**2, x**3, x**4, x**6], index=['1','2','3','4','6'])

# %%
df_1.corr()
# Out:
#     0   1         2         3         4         5         6         7  \
# 0 NaN NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 1 NaN NaN       NaN       NaN       NaN       NaN       NaN       NaN
# 2 NaN NaN  1.000000  0.993673  0.988137  0.984937  0.983024  0.981811
# 3 NaN NaN  0.993673  1.000000  0.999120  0.998089  0.997355  0.996850
# 4 NaN NaN  0.988137  0.999120  1.000000  0.999802  0.999523  0.999294
# 5 NaN NaN  0.984937  0.998089  0.999802  1.000000  0.999940  0.999844
# 6 NaN NaN  0.983024  0.997355  0.999523  0.999940  1.000000  0.999978
# 7 NaN NaN  0.981811  0.996850  0.999294  0.999844  0.999978  1.000000
# 8 NaN NaN  0.981000  0.996497  0.999121  0.999757  0.999939  0.999990
# 9 NaN NaN  0.980432  0.996244  0.998991  0.999686  0.999901  0.999973
#
#           8         9
# 0       NaN       NaN
# 1       NaN       NaN
# 2  0.981000  0.980432
# 3  0.996497  0.996244
# 4  0.999121  0.998991
# 5  0.999757  0.999686
# 6  0.999939  0.999901
# 7  0.999990  0.999973
# 8  1.000000  0.999995
# 9  0.999995  1.000000
